# %%
from tabulate import tabulate

# %%
# Task 1
total_money = 0
seat_fair = 25
discount = 0

train1_Departure_Seats = 480
train1_Arrival_Seats = 480

train2_Departure_Seats = 480
train2_Arrival_Seats = 480

train3_Departure_Seats = 480
train3_Arrival_Seats = 480

train4_Departure_Seats = 480
train4_Arrival_Seats = 640

train1_Up_Money = 0
train1_Down_Money = 0

train2_Up_Money = 0
train2_Down_Money = 0

train3_Up_Money = 0
train3_Down_Money = 0

train4_Up_Money = 0
train4_Down_Money = 0


data = [
    ['',     'Trip1',    '',     'Trip2',    '',     'Trip3',    '',     'Trip4',    ''],
    ['',     'Departure','Arrival', 'Departure','Arrival', 'Departure','Arrival', 'Departure','Arrival'],
    ['Time', '09:00',    '10:00', '11:00', '12:00', '13:00', '14:00', '15:00', '16:00'],
    ['Available Seats',train1_Departure_Seats,train1_Arrival_Seats,train2_Departure_Seats,train2_Arrival_Seats,train3_Departure_Seats,train3_Arrival_Seats,train4_Departure_Seats,train4_Arrival_Seats]
]
table = tabulate(data) 
# Screen display
print("Screen Display")
print(table)
print(f"\nMoney Collected")
print(f"Trip 1 UP Money   = ${train1_Up_Money}")
print(f"Trip 1 Down Money = ${train1_Down_Money}")
print(f"Trip 2 UP Money   = ${train2_Up_Money}")
print(f"Trip 2 Down Money = ${train2_Down_Money}")
print(f"Trip 3 UP Money   = ${train3_Up_Money}")
print(f"Trip 3 Down Money = ${train3_Down_Money}")
print(f"Trip 4 UP Money   = ${train4_Up_Money}")
print(f"Trip 4 Down Money = ${train4_Down_Money}")
# Out:
# Screen Display
# ---------------  ---------  -------  ---------  -------  ---------  -------  ---------  -------
#                  Trip1               Trip2               Trip3               Trip4
#                  Departure  Arrival  Departure  Arrival  Departure  Arrival  Departure  Arrival
# Time             09:00      10:00    11:00      12:00    13:00      14:00    15:00      16:00
# Available Seats  480        480      480        480      480        480      480        640
# ---------------  ---------  -------  ---------  -------  ---------  -------  ---------  -------
#
# Money Collected
# Trip 1 UP Money   = $0
# Trip 1 Down Money = $0
# Trip 2 UP Money   = $0
# Trip 2 Down Money = $0
# Trip 3 UP Money   = $0
# Trip 3 Down Money = $0
# Trip 4 UP Money   = $0
# Trip 4 Down Money = $0

# %%
# Task 2
# Purchasing Tickets
print("Screen Display")
print(table)

passenger = 1
booking = 'open'
while (booking == 'open'):
    print(f"\nPassenger No. {passenger}")
    continue_booking = input("Do you want to book ticket (Yes or No): ")
    continue_booking = continue_booking.upper()
    if (continue_booking == 'NO'):
        booking = "close"
        break
    else:
        booking = "open"
        print("Booking is open!")
    
    print("How many tickets do you want?")
    tickets = int(input())
    
    departure_time = int(input("Enter Departure Time (9,11,13,15): "))
    if (departure_time!=9 and departure_time!=11 and departure_time!=13 and departure_time!=15):
        print("Invalid Departure time.\nPlease select a valid Departure Time. Thank you!")
        continue
    if ((departure_time==9 and train1_Departure_Seats=='Closed!')or(departure_time==11 and train2_Departure_Seats=='Closed!')or(departure_time==13 and train3_Departure_Seats=='Closed!')or(departure_time==15 and train4_Departure_Seats=='Closed!')):
        print("The Selected Depature Time Trip you chose has been closed!")
        print("Please select a different time!\nThank you!")
        continue
    if ((departure_time==9 and tickets>train1_Departure_Seats)or(departure_time==11 and tickets>train2_Departure_Seats)or(departure_time==13 and tickets>train3_Departure_Seats)or(departure_time==15 and tickets>train4_Departure_Seats)):
        print("The Selected Depature Time Trip you chose does not have enough seats!")
        print("Please select a different time or reduce the number of tickets!\nThank you!")
        continue
        
    if (departure_time==9 and train1_Arrival_Seats=='Closed!' and train2_Arrival_Seats=='Closed!' and train3_Arrival_Seats=='Closed!' and train4_Arrival_Seats=='Closed!'):
        print("Sorry! There are no Arrival Trips available after this Departure. So we cannot book your tickets.")
    elif (departure_time==11 and train2_Arrival_Seats=='Closed!' and train3_Arrival_Seats=='Closed!' and train4_Arrival_Seats=='Closed!'):
        print("Sorry! There are no Arrival Trips available after this Departure. So we cannot book your tickets.")
    elif (departure_time==13 and train3_Arrival_Seats=='Closed!' and train4_Arrival_Seats=='Closed!'):
        print("Sorry! There are no Arrival Trips available after this Departure. So we cannot book your tickets.")
    elif (departure_time==15 and train4_Arrival_Seats=='Closed!'):
        print("Sorry! There are no Arrival Trips available after this Departure. So we cannot book your tickets.")
        

    
    arrival_time = int(input("Enter Arrival Time (10,12,14,16): "))
    if (arrival_time!=10 and arrival_time!=12 and arrival_time!=14 and arrival_time!=16):
        print("Invalid Arrival Time.\nPlease select a valid Arrival Time. Thank you!")
        continue
    elif (arrival_time<departure_time):
        print("Arrival Time cannot be before Depature Time.\nPlease select a different Arrival Time. Thank you!")
        continue
    if ((arrival_time==10 and train1_Arrival_Seats=='Closed!')or(arrival_time==12 and train2_Arrival_Seats=='Closed!')or(arrival_time==14 and train3_Arrival_Seats=='Closed!')or(arrival_time==15 and train4_Arrival_Seats=='Closed!')):
        print("The Selected Arival Time Trip you chose has been closed!")
        print("Please select a different time!\nThank you!")
        continue
    if ((arrival_time==10 and tickets>train1_Arrival_Seats)or(arrival_time==12 and tickets>train2_Arrival_Seats)or(arrival_time==14 and tickets>train3_Arrival_Seats)or(arrival_time==15 and tickets>train4_Arrival_Seats)):
        print("The Selected Arrival Time Trip you chose does not have enough seats!")
        print("Please select a different time or reduce the number of tickets!\nThank you!")
        continue

    money = tickets*25
    if (tickets>=10 and tickets<=80):
        discount_on_seats = tickets//10
        discount = discount_on_seats * 25
        print(f"Total Amount: ${money}")
        print(f"Discount: ${discount}")
        money = money - discount
    print(f"Price to be payed: ${money}")
    
    if (departure_time==9):
        train1_Up_Money = train1_Up_Money + money
    elif (departure_time==11):
        train2_Up_Money = train2_Up_Money + money
    elif (departure_time==13):
        train3_Up_Money = train3_Up_Money + money
    elif (departure_time==15):
        train4_Up_Money = train4_Up_Money + money
        
    if (arrival_time==10):
        train1_Down_Money = train1_Down_Money + money
    elif (arrival_time==12):
        train2_Down_Money = train2_Down_Money + money
    elif (arrival_time==14):
        train3_Down_Money = train3_Down_Money + money
    elif (arrival_time==16):
        train4_Down_Money = train4_Down_Money + money
        
    total_money = total_money+money
    
    
    if (departure_time==9):
        train1_Departure_Seats = train1_Departure_Seats - tickets
    elif (departure_time==11):
        train2_Departure_Seats = train2_Departure_Seats - tickets
    elif (departure_time==13):
        train3_Departure_Seats = train3_Departure_Seats - tickets
    elif (departure_time==15):
        train4_Departure_Seats = train4_Departure_Seats - tickets
        
    if (arrival_time==10):
        train1_Arrival_Seats = train1_Arrival_Seats - tickets
    elif (arrival_time==12):
        train2_Arrival_Seats = train2_Arrival_Seats - tickets
    elif (arrival_time==14):
        train3_Arrival_Seats = train3_Arrival_Seats - tickets
    elif (arrival_time==16):
        train4_Arrival_Seats = train4_Arrival_Seats - tickets
        
    if (train1_Arrival_Seats == 0):
        train1_Arrival_Seats = 'Closed!'
    if (train2_Arrival_Seats == 0):
        train2_Arrival_Seats = 'Closed!'
    if (train3_Arrival_Seats == 0):
        train3_Arrival_Seats = 'Closed!'
    if (train4_Arrival_Seats == 0):
        train4_Arrival_Seats = 'Closed!'
        
    if (train1_Departure_Seats == 0):
        train1_Departure_Seats = 'Closed!'
    if (train2_Departure_Seats == 0):
        train2_Departure_Seats = 'Closed!'
    if (train3_Departure_Seats == 0):
        train3_Departure_Seats = 'Closed!'
    if (train4_Departure_Seats == 0):
        train4_Departure_Seats = 'Closed!'
      
    
    if ((train1_Departure_Seats=='Closed!')and(train2_Departure_Seats=='Closed!')and(train3_Departure_Seats=='Closed!')and(train4_Departure_Seats=='Closed!')):
        booking = 'close'
        print("Booking closed!")
    elif (train1_Arrival_Seats=='Closed!' and train2_Arrival_Seats=='Closed!' and train3_Arrival_Seats=='Closed!' and train4_Arrival_Seats=='Closed!'):
        booking = 'close'
        print("Booking closed!")
    elif (train1_Departure_Seats=='Closed!' and train2_Arrival_Seats=='Closed!' and train3_Arrival_Seats=='Closed!' and train4_Arrival_Seats=='Closed!'):
        booking = 'close'
        print("Booking closed!")
    elif (train1_Departure_Seats=='Closed!' and train2_Departure_Seats=='Closed!' and train3_Arrival_Seats=='Closed!' and train4_Arrival_Seats=='Closed!'):
        booking = 'close'
        print("Booking closed!")
    elif (train1_Departure_Seats=='Closed!' and train2_Departure_Seats=='Closed!' and train3_Departure_Seats=='Closed!' and train4_Arrival_Seats=='Closed!'):
        booking = 'close'
        print("Booking closed!")
        
    
    data = [
        ['',     'Trip1',    '',     'Trip2',    '',     'Trip3',    '',     'Trip4',    ''],
        ['',     'Departure','Arrival', 'Departure','Arrival', 'Departure','Arrival', 'Departure','Arrival'],
        ['Time', '09:00',    '10:00', '11:00', '12:00', '13:00', '14:00', '15:00', '16:00'],
        ['Available Seats',train1_Departure_Seats,train1_Arrival_Seats,train2_Departure_Seats,train2_Arrival_Seats,train3_Departure_Seats,train3_Arrival_Seats,train4_Departure_Seats,train4_Arrival_Seats]
        ]
    table = tabulate(data) 
    
    print("\nScreen Display")
    print(table)
    
    print(f"\nMoney Collected")
    print(f"Trip 1 UP Money   = ${train1_Up_Money}")
    print(f"Trip 1 Down Money = ${train1_Down_Money}")
    print(f"Trip 2 UP Money   = ${train2_Up_Money}")
    print(f"Trip 2 Down Money = ${train2_Down_Money}")
    print(f"Trip 3 UP Money   = ${train3_Up_Money}")
    print(f"Trip 3 Down Money = ${train3_Down_Money}")
    print(f"Trip 4 UP Money   = ${train4_Up_Money}")
    print(f"Trip 4 Down Money = ${train4_Down_Money}")
    
    
    print(f"\nTotal Money Collected till now: ${total_money}")
    print(f"Booking {booking}")

    passenger = passenger + 1
# Out:
# Screen Display
# ---------------  ---------  -------  ---------  -------  ---------  -------  ---------  -------
#                  Trip1               Trip2               Trip3               Trip4
#                  Departure  Arrival  Departure  Arrival  Departure  Arrival  Departure  Arrival
# Time             09:00      10:00    11:00      12:00    13:00      14:00    15:00      16:00
# Available Seats  480        480      480        480      480        480      480        640
# ---------------  ---------  -------  ---------  -------  ---------  -------  ---------  -------
#
# Passenger No. 1
# Do you want to book ticket (Yes or No): yes
# Booking is open!
# How many tickets do you want?
# 80
# Enter Departure Time (9,11,13,15): 9
# Enter Arrival Time (10,12,14,16): 16
# Total Amount: $2000
# Discount: $200
# Price to be payed: $1800
#
# Screen Display
# ---------------  ---------  -------  ---------  -------  ---------  -------  ---------  -------
# ...

# %%
# Task 3

if (train1_Departure_Seats == 'Closed!'):
    train1_Departure_Seats = 0
if (train2_Departure_Seats == 'Closed!'):
    train2_Departure_Seats = 0
if (train3_Departure_Seats == 'Closed!'):
    train3_Departure_Seats = 0
if (train4_Departure_Seats == 'Closed!'):
    train4_Departure_Seats = 0
    
if (train1_Arrival_Seats == 'Closed!'):
    train1_Arrival_Seats = 0
if (train2_Arrival_Seats == 'Closed!'):
    train2_Arrival_Seats = 0
if (train3_Arrival_Seats == 'Closed!'):
    train3_Arrival_Seats = 0
if (train4_Arrival_Seats == 'Closed!'):
    train4_Arrival_Seats = 0


train1_Up_Passengers   = 480 - train1_Departure_Seats
train1_Down_Passengers = 480 - train1_Arrival_Seats

train2_Up_Passengers   = 480 - train2_Departure_Seats
train2_Down_Passengers = 480 - train2_Arrival_Seats 

train3_Up_Passengers   = 480 - train3_Departure_Seats
train3_Down_Passengers = 480 - train3_Arrival_Seats

train4_Up_Passengers   = 480 - train4_Departure_Seats 
train4_Down_Passengers = 640 - train4_Arrival_Seats 

total_Passengers = train1_Up_Passengers+train1_Down_Passengers+train2_Up_Passengers+train2_Down_Passengers+train3_Up_Passengers+train3_Down_Passengers+train4_Up_Passengers+train4_Down_Passengers

print(f"Passengers in each journey.")
print(f"Trip 1 UP Passengers:   {train1_Up_Passengers}")
print(f"Trip 1 Down Passengers: {train1_Down_Passengers}")
print(f"Trip 2 UP Passengers:   {train2_Up_Passengers}")
print(f"Trip 2 Down Passengers: {train2_Down_Passengers}")
print(f"Trip 3 UP Passengers:   {train3_Up_Passengers}")
print(f"Trip 3 Down Passengers: {train3_Down_Passengers}")
print(f"Trip 4 UP Passengers:   {train4_Up_Passengers}")
print(f"Trip 4 Down Passengers: {train4_Down_Passengers}")

print(f"\nTotal Passengers that travelled today: {total_Passengers}")
    
print(f"\nMoney Collected")
print(f"Trip 1 UP Money   = ${train1_Up_Money}")
print(f"Trip 1 Down Money = ${train1_Down_Money}")
print(f"Trip 2 UP Money   = ${train2_Up_Money}")
print(f"Trip 2 Down Money = ${train2_Down_Money}")
print(f"Trip 3 UP Money   = ${train3_Up_Money}")
print(f"Trip 3 Down Money = ${train3_Down_Money}")
print(f"Trip 4 UP Money   = ${train4_Up_Money}")
print(f"Trip 4 Down Money = ${train4_Down_Money}")
        
print(f"\nTotal Money Collected till now: ${total_money}")

max_passengers = max(train1_Up_Passengers,train1_Down_Passengers,train2_Up_Passengers,train2_Down_Passengers,train3_Up_Passengers,train3_Down_Passengers,train4_Up_Passengers,train4_Down_Passengers)
if (max_passengers == train1_Up_Passengers):
    print("The train 1 going up at 09:00 had the most passengers.")
elif (max_passengers == train2_Up_Passengers):
    print("The train 2 going up at 11:00 had the most passengers.")
elif (max_passengers == train3_Up_Passengers):
    print("The train 3 going up at 13:00 had the most passengers.")
elif (max_passengers == train4_Up_Passengers):
    print("The train 4 going up at 15:00 had the most passengers.")
elif (max_passengers == train1_Down_Passengers):
    print("The train 1 going down at 10:00 had the most passengers.")
elif (max_passengers == train2_Down_Passengers):
    print("The train 2 going down at 12:00 had the most passengers.")
elif (max_passengers == train3_Down_Passengers):
    print("The train 3 going down at 14:00 had the most passengers.")
elif (max_passengers == train4_Down_Passengers):
    print("The train 4 going down at 16:00 had the most passengers.")
# Out:
# Passengers in each journey.
# Trip 1 UP Passengers:   480
# Trip 1 Down Passengers: 0
# Trip 2 UP Passengers:   480
# Trip 2 Down Passengers: 0
# Trip 3 UP Passengers:   160
# Trip 3 Down Passengers: 480
# Trip 4 UP Passengers:   0
# Trip 4 Down Passengers: 640
#
# Total Passengers that travelled today: 2240
#
# Money Collected
# Trip 1 UP Money   = $11800
# Trip 1 Down Money = $0
# Trip 2 UP Money   = $12000
# Trip 2 Down Money = $0
# Trip 3 UP Money   = $4000
# Trip 3 Down Money = $12000
# Trip 4 UP Money   = $0
# Trip 4 Down Money = $15800
#
# Total Money Collected till now: $27800
# The train 4 going down at 16:00 had the most passengers.
